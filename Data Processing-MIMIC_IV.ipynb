# %%
import pandas as pd
from itertools import islice
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedShuffleSplit

import seaborn as sn
sn.set_theme(style="white", palette="rocket_r")

# %%
# Process the time-series
def timeseries_processing(timeseries, labels, hour):
    timeseries.reset_index(level=1, inplace=True)
    timeseries.time = pd.to_timedelta(timeseries.time, errors='coerce')
    
    # Convert the time-stamps into minutes
    timeseries.time = timeseries.time.astype(int)/(1000000000*60)
        
    # Add time of event
    timeseries = timeseries.merge(labels, left_index=True, right_index=True)
    
    # Only keep those timestamps with more than time before the event for prediction
    timeseries = timeseries[timeseries['time'] <= (timeseries['actualiculos'] - hour*60)]
    
    # Drop the labels column, we will add them at the end for consistency and to avoid redundancy
    timeseries = timeseries.drop(columns=['actualiculos', 'actualhospitalmortality'])
    
    timeseries.reset_index(inplace=True)
    timeseries.set_index(['patient', 'time'], inplace=True)
    
    # Get the means and standard deviations of the timeseries
    df_mean = pd.concat({'mean': timeseries.groupby(level=0, axis=0).mean()}, axis=1).swaplevel(axis=1)
    df_mean.columns = df_mean.columns.droplevel(level = 1)
    df_mean = df_mean.add_suffix('_mean')

    df_std = pd.concat({'std': timeseries.groupby(level=0, axis=0).std()}, axis=1).swaplevel(axis=1)
    df_std.columns = df_std.columns.droplevel(level = 1)
    df_std = df_std.add_suffix('_std')

    timeseries = df_mean.merge(df_std, left_index=True, right_index=True)
    
    return timeseries

# %%
labels = pd.read_csv('preprocessed_labels.csv', index_col='patient')
labels['actualiculos'] = labels['actualiculos']*24*60

# %%
labels
# Out:
#           uniquepid  patienthealthsystemstayid  actualhospitalmortality  \
# patient
# 30000153   12466550                   23998182                        0
# 30000213   13180007                   27543152                        0
# 30000484   18421337                   22413411                        0
# 30000646   12207593                   22795209                        1
# 30001148   12980335                   23552849                        0
# ...             ...                        ...                      ...
# 39999301   16180713                   20178444                        1
# 39999384   15498623                   27161460                        0
# 39999552   11256534                   26910235                        0
# 39999562   15403458                   25335698                        0
# 39999810   17840864                   22695803                        0
#
#           actualiculos
# patient
# 30000153   2357.166667
# 30000213   2354.800000
# 30000484   3569.600000
# 30000646   6764.433333
# 30001148   1634.583333
# ...                ...
# 39999301   1651.550000
# 39999384   1837.100000
# 39999552   1681.366667
# 39999562   7194.666667
# 39999810   6830.950000
#
# [76938 rows x 4 columns]

# %% [markdown]
# # Diagnosis

# %%
diagnosis = pd.read_csv('diagnosis.csv')

# %%
diagnosis
# Out:
#         subject_id   stay_id  seq_num icd_code  icd_version  \
# 0         10000032  32952584        1     4589            9
# 1         10000032  32952584        2    07070            9
# 2         10000032  32952584        3      V08            9
# 3         10000032  33258284        1     5728            9
# 4         10000032  33258284        2    78959            9
# ...            ...       ...      ...      ...          ...
# 946687    19999828  30712109        1     K632           10
# 946688    19999828  32917002        1    E1110           10
# 946689    19999828  32917002        2    Z7984           10
# 946690    19999914  32002659        1    R4182           10
# 946691    19999987  34731548        1      431            9
#
#                                                 icd_title
# 0                                         HYPOTENSION NOS
# 1       UNSPECIFIED VIRAL HEPATITIS C WITHOUT HEPATIC ...
# 2                              ASYMPTOMATIC HIV INFECTION
# 3                                OTH SEQUELA, CHR LIV DIS
# 4                                           OTHER ASCITES
# ...                                                   ...
# 946687                               Fistula of intestine
# 946688  Type 2 diabetes mellitus with ketoacidosis wit...
# 946689  Long term (current) use of oral hypoglycemic d...
# 946690                 Altered mental status, unspecified
# 946691                           INTRACEREBRAL HEMORRHAGE
#
# [946692 rows x 6 columns]

# %%
edstays = pd.read_csv('edstays.csv')

# %%
edstays
# Out:
#         subject_id     hadm_id   stay_id               intime  \
# 0         10000032  22595853.0  33258284  2180-05-06 19:17:00
# 1         10000032  22841357.0  38112554  2180-06-26 15:54:00
# 2         10000032  25742920.0  35968195  2180-08-05 20:58:00
# 3         10000032  29079034.0  32952584  2180-07-22 16:24:00
# 4         10000032  29079034.0  39399961  2180-07-23 05:54:00
# ...            ...         ...       ...                  ...
# 447707    19999784  26194817.0  35692999  2119-06-18 14:21:00
# 447708    19999828  25744818.0  32917002  2149-01-08 09:11:00
# 447709    19999828  29734428.0  30712109  2147-07-17 17:18:00
# 447710    19999914         NaN  32002659  2158-12-24 11:41:00
# 447711    19999987  23865745.0  34731548  2145-11-02 19:28:00
#
#                     outtime gender                    race arrival_transport  \
# 0       2180-05-06 23:30:00      F                   WHITE         AMBULANCE
# 1       2180-06-26 21:31:00      F                   WHITE         AMBULANCE
# 2       2180-08-06 01:44:00      F                   WHITE         AMBULANCE
# 3       2180-07-23 05:54:00      F                   WHITE         AMBULANCE
# 4       2180-07-23 14:00:00      F                   WHITE         AMBULANCE
# ...                     ...    ...                     ...               ...
# 447707  2119-06-18 21:09:29      M  BLACK/AFRICAN AMERICAN           WALK IN
# 447708  2149-01-08 18:12:00      F                   WHITE         AMBULANCE
# 447709  2147-07-18 17:34:00      F                   WHITE           WALK IN
# 447710  2158-12-24 11:56:00      F                 UNKNOWN           UNKNOWN
# 447711  2145-11-02 22:59:00      F                 UNKNOWN         AMBULANCE
#
#        disposition
# 0         ADMITTED
# 1         ADMITTED
# 2         ADMITTED
# 3             HOME
# 4         ADMITTED
# ...            ...
# 447707    ADMITTED
# 447708    ADMITTED
# 447709    ADMITTED
# 447710      ELOPED
# 447711    ADMITTED
#
# [447712 rows x 9 columns]

# %%
ED = pd.merge(diagnosis, edstays, left_on=['subject_id', 'stay_id'], right_on=['subject_id', 'stay_id'], how='right')

# %%
ED
# Out:
#         subject_id   stay_id  seq_num icd_code  icd_version  \
# 0         10000032  33258284      1.0     5728          9.0
# 1         10000032  33258284      2.0    78959          9.0
# 2         10000032  33258284      3.0    07070          9.0
# 3         10000032  33258284      4.0      V08          9.0
# 4         10000032  38112554      1.0    78959          9.0
# ...            ...       ...      ...      ...          ...
# 947869    19999828  32917002      1.0    E1110         10.0
# 947870    19999828  32917002      2.0    Z7984         10.0
# 947871    19999828  30712109      1.0     K632         10.0
# 947872    19999914  32002659      1.0    R4182         10.0
# 947873    19999987  34731548      1.0      431          9.0
#
#                                                 icd_title     hadm_id  \
# 0                                OTH SEQUELA, CHR LIV DIS  22595853.0
# 1                                           OTHER ASCITES  22595853.0
# 2       UNSPECIFIED VIRAL HEPATITIS C WITHOUT HEPATIC ...  22595853.0
# 3                              ASYMPTOMATIC HIV INFECTION  22595853.0
# 4                                           OTHER ASCITES  22841357.0
# ...                                                   ...         ...
# 947869  Type 2 diabetes mellitus with ketoacidosis wit...  25744818.0
# 947870  Long term (current) use of oral hypoglycemic d...  25744818.0
# 947871                               Fistula of intestine  29734428.0
# 947872                 Altered mental status, unspecified         NaN
# 947873                           INTRACEREBRAL HEMORRHAGE  23865745.0
#
#                      intime              outtime gender     race  \
# 0       2180-05-06 19:17:00  2180-05-06 23:30:00      F    WHITE
# 1       2180-05-06 19:17:00  2180-05-06 23:30:00      F    WHITE
# 2       2180-05-06 19:17:00  2180-05-06 23:30:00      F    WHITE
# 3       2180-05-06 19:17:00  2180-05-06 23:30:00      F    WHITE
# 4       2180-06-26 15:54:00  2180-06-26 21:31:00      F    WHITE
# ...                     ...                  ...    ...      ...
# 947869  2149-01-08 09:11:00  2149-01-08 18:12:00      F    WHITE
# 947870  2149-01-08 09:11:00  2149-01-08 18:12:00      F    WHITE
# 947871  2147-07-17 17:18:00  2147-07-18 17:34:00      F    WHITE
# 947872  2158-12-24 11:41:00  2158-12-24 11:56:00      F  UNKNOWN
# 947873  2145-11-02 19:28:00  2145-11-02 22:59:00      F  UNKNOWN
#
#        arrival_transport disposition
# 0              AMBULANCE    ADMITTED
# 1              AMBULANCE    ADMITTED
# 2              AMBULANCE    ADMITTED
# 3              AMBULANCE    ADMITTED
# 4              AMBULANCE    ADMITTED
# ...                  ...         ...
# 947869         AMBULANCE    ADMITTED
# 947870         AMBULANCE    ADMITTED
# 947871           WALK IN    ADMITTED
# 947872           UNKNOWN      ELOPED
# 947873         AMBULANCE    ADMITTED
#
# [947874 rows x 13 columns]

# %%
searchfor = ['myocardial', 'coronary artery', 'acute coronary', 'PTCA', 'coronary syndrome', 'infarction', 'non-Q']
ED_MI = ED[ED.icd_title.str.contains('|'.join(searchfor), na=False)]

# %%
labels['patient'] = labels.index
ED_linked = pd.merge(ED_MI, labels, left_on=['subject_id', 'hadm_id'], right_on=['uniquepid', 'patienthealthsystemstayid'], how='left')

# %%
ED_linked
# Out:
#       subject_id   stay_id  seq_num icd_code  icd_version  \
# 0       10001667  33673933      1.0     I639         10.0
# 1       10001884  34226385      3.0    I2510         10.0
# 2       10003299  32908139      2.0     I639         10.0
# 3       10004606  34549994      3.0    I2510         10.0
# 4       10005464  33455046      2.0    I2510         10.0
# ...          ...       ...      ...      ...          ...
# 4798    19988997  39070828      1.0     I214         10.0
# 4799    19989783  32849404      5.0     I214         10.0
# 4800    19990106  39207830      3.0    I2510         10.0
# 4801    19993089  39865345      1.0     I214         10.0
# 4802    19995832  30969016      4.0    I2510         10.0
#
#                                               icd_title     hadm_id  \
# 0                      Cerebral infarction, unspecified  22672901.0
# 1     Athscl heart disease of native coronary artery...  28669374.0
# 2                      Cerebral infarction, unspecified  29323205.0
# 3     Athscl heart disease of native coronary artery...         NaN
# 4     Athscl heart disease of native coronary artery...         NaN
# ...                                                 ...         ...
# 4798    Non-ST elevation (NSTEMI) myocardial infarction  29807937.0
# 4799    Non-ST elevation (NSTEMI) myocardial infarction  24282820.0
# 4800  Athscl heart disease of native coronary artery...  25163479.0
# 4801    Non-ST elevation (NSTEMI) myocardial infarction  20556903.0
# 4802  Athscl heart disease of native coronary artery...  23014132.0
#
#                    intime              outtime gender                    race  \
# 0     2173-08-22 01:40:00  2173-08-22 17:17:16      F                   WHITE
# 1     2130-11-19 13:41:00  2130-11-20 10:46:00      F  BLACK/AFRICAN AMERICAN
# 2     2181-10-22 11:46:00  2181-10-22 19:09:15      F  BLACK/AFRICAN AMERICAN
# 3     2159-05-17 19:15:00  2159-05-17 23:41:00      F                   WHITE
# 4     2165-06-28 02:17:00  2165-06-28 09:31:00      M         WHITE - RUSSIAN
# ...                   ...                  ...    ...                     ...
# 4798  2174-06-27 14:13:00  2174-06-27 15:23:00      M                 UNKNOWN
# 4799  2130-08-02 12:52:00  2130-08-02 17:28:05      M  BLACK/AFRICAN AMERICAN
# 4800  2166-04-06 16:58:00  2166-04-07 15:33:00      M  BLACK/AFRICAN AMERICAN
# 4801  2156-09-10 18:29:00  2156-09-10 21:43:58      F                   WHITE
# 4802  2185-05-04 21:45:00  2185-05-05 02:20:00      M                 UNKNOWN
#
#      arrival_transport disposition   uniquepid  patienthealthsystemstayid  \
# 0            AMBULANCE    ADMITTED         NaN                        NaN
# 1              WALK IN        HOME         NaN                        NaN
# 2            AMBULANCE    ADMITTED         NaN                        NaN
# 3            AMBULANCE        HOME         NaN                        NaN
# 4            AMBULANCE        HOME         NaN                        NaN
# ...                ...         ...         ...                        ...
# 4798         AMBULANCE    ADMITTED         NaN                        NaN
# 4799         AMBULANCE    ADMITTED  19989783.0                 24282820.0
# 4800         AMBULANCE        HOME         NaN                        NaN
# 4801         AMBULANCE    ADMITTED         NaN                        NaN
# 4802           UNKNOWN    ADMITTED  19995832.0                 23014132.0
#
#       actualhospitalmortality  actualiculos     patient
# 0                         NaN           NaN         NaN
# 1                         NaN           NaN         NaN
# 2                         NaN           NaN         NaN
# 3                         NaN           NaN         NaN
# 4                         NaN           NaN         NaN
# ...                       ...           ...         ...
# 4798                      NaN           NaN         NaN
# 4799                      0.0        6987.1  32711376.0
# 4800                      NaN           NaN         NaN
# 4801                      NaN           NaN         NaN
# 4802                      0.0        5213.5  34817232.0
#
# [4803 rows x 18 columns]

# %%
ED_linked['actualhospitalmortality'].isna().sum()/4803, ED_linked['actualiculos'].isna().sum()/4803
# Out:
# (0.6953987091401208, 0.6953987091401208)

# %%
# Remove those with missing hospital discharge status or length of stay
ED_linked = ED_linked[ED_linked['actualhospitalmortality'].notna()]

# %%
columns_we_care_about = ['patient', 'actualhospitalmortality', 'actualiculos']
ED_linked = ED_linked[columns_we_care_about]

# %%
ED_linked = ED_linked.set_index('patient')

# %%
ED_linked
# Out:
#             actualhospitalmortality  actualiculos
# patient
# 32506122.0                      0.0   2913.066667
# 34992648.0                      0.0   8349.433333
# 33768181.0                      0.0   1074.250000
# 32769810.0                      0.0   9067.533333
# 31203589.0                      0.0   1579.316667
# ...                             ...           ...
# 31123584.0                      0.0  28613.483333
# 38791957.0                      0.0   3897.983333
# 34859288.0                      0.0   2816.683333
# 32711376.0                      0.0   6987.100000
# 34817232.0                      0.0   5213.500000
#
# [1463 rows x 2 columns]

# %% [markdown]
# # Timeseries

# %%
timeseries = pd.read_csv('preprocessed_timeseries.csv', index_col=['patient', 'time'])

# %%
timeseries
# Out:
#                             Activity / Mobility (JH-HLM)  Apnea Interval  \
# patient  time
# 30000153 -1 days +23:51:00                           NaN             NaN
#          -1 days +23:52:00                           NaN            20.0
#          -1 days +23:56:00                           NaN             NaN
#          -1 days +23:57:00                           NaN             NaN
#          -1 days +23:59:00                           NaN             NaN
# ...                                                  ...             ...
# 39999810 4 days 13:24:00                             NaN             NaN
#          4 days 15:23:00                             2.0             NaN
#          4 days 15:24:00                             NaN             NaN
#          4 days 15:26:00                             NaN             NaN
#          4 days 16:23:00                             NaN             NaN
#
#                             Arterial Blood Pressure Alarm - High  \
# patient  time
# 30000153 -1 days +23:51:00                                   NaN
#          -1 days +23:52:00                                   NaN
#          -1 days +23:56:00                                   NaN
#          -1 days +23:57:00                                   NaN
#          -1 days +23:59:00                                   NaN
# ...                                                          ...
# 39999810 4 days 13:24:00                                     NaN
#          4 days 15:23:00                                     NaN
#          4 days 15:24:00                                     NaN
#          4 days 15:26:00                                     NaN
#          4 days 16:23:00                                     NaN
#
#                             Arterial Blood Pressure Alarm - Low  \
# patient  time
# 30000153 -1 days +23:51:00                                  NaN
#          -1 days +23:52:00                                  NaN
#          -1 days +23:56:00                                  NaN
#          -1 days +23:57:00                                  NaN
#          -1 days +23:59:00                                  NaN
# ...                                                         ...
# 39999810 4 days 13:24:00                                    NaN
#          4 days 15:23:00                                    NaN
#          4 days 15:24:00                                    NaN
#          4 days 15:26:00                                    NaN
#          4 days 16:23:00                                    NaN
#
#                             Arterial Blood Pressure diastolic  \
# patient  time
# 30000153 -1 days +23:51:00                                NaN
#          -1 days +23:52:00                                NaN
#          -1 days +23:56:00                                NaN
#          -1 days +23:57:00                                NaN
#          -1 days +23:59:00                                NaN
# ...                                                       ...
# 39999810 4 days 13:24:00                                  NaN
#          4 days 15:23:00                                  NaN
#          4 days 15:24:00                                  NaN
#          4 days 15:26:00                                  NaN
#          4 days 16:23:00                                  NaN
#
#                             Arterial Blood Pressure mean  \
# patient  time
# 30000153 -1 days +23:51:00                           NaN
#          -1 days +23:52:00                           NaN
#          -1 days +23:56:00                           NaN
#          -1 days +23:57:00                           NaN
#          -1 days +23:59:00                           NaN
# ...                                                  ...
# 39999810 4 days 13:24:00                             NaN
#          4 days 15:23:00                             NaN
#          4 days 15:24:00                             NaN
#          4 days 15:26:00                             NaN
#          4 days 16:23:00                             NaN
#
#                             Arterial Blood Pressure systolic  \
# patient  time
# 30000153 -1 days +23:51:00                               NaN
#          -1 days +23:52:00                               NaN
#          -1 days +23:56:00                               NaN
#          -1 days +23:57:00                               NaN
#          -1 days +23:59:00                               NaN
# ...                                                      ...
# 39999810 4 days 13:24:00                                 NaN
#          4 days 15:23:00                                 NaN
#          4 days 15:24:00                                 NaN
#          4 days 15:26:00                                 NaN
#          4 days 16:23:00                                 NaN
#
#                             Chloride (serum)  Creatinine (serum)  \
# patient  time
# 30000153 -1 days +23:51:00               NaN                 NaN
#          -1 days +23:52:00               NaN                 NaN
#          -1 days +23:56:00               NaN                 NaN
#          -1 days +23:57:00               NaN                 NaN
#          -1 days +23:59:00               NaN                 NaN
# ...                                      ...                 ...
# 39999810 4 days 13:24:00                 NaN                 NaN
#          4 days 15:23:00                 NaN                 NaN
#          4 days 15:24:00                 NaN                 NaN
#          4 days 15:26:00                 NaN                 NaN
#          4 days 16:23:00                 NaN                 NaN
#
#                             Current Dyspnea Assessment  ...  Strength R Arm  \
# patient  time                                           ...
# 30000153 -1 days +23:51:00                         NaN  ...             NaN
#          -1 days +23:52:00                         NaN  ...             NaN
#          -1 days +23:56:00                         NaN  ...             NaN
#          -1 days +23:57:00                         NaN  ...             NaN
#          -1 days +23:59:00                         NaN  ...             NaN
# ...                                                ...  ...             ...
# 39999810 4 days 13:24:00                           NaN  ...             NaN
#          4 days 15:23:00                           NaN  ...             5.0
#          4 days 15:24:00                           NaN  ...             NaN
#          4 days 15:26:00                           NaN  ...             NaN
#          4 days 16:23:00                           NaN  ...             NaN
#
#                             Strength R Leg  Temperature Fahrenheit  \
# patient  time
# 30000153 -1 days +23:51:00             NaN                     NaN
#          -1 days +23:52:00             NaN                     NaN
#          -1 days +23:56:00             NaN                     NaN
#          -1 days +23:57:00             NaN                     NaN
#          -1 days +23:59:00             NaN                    96.8
# ...                                    ...                     ...
# 39999810 4 days 13:24:00               NaN                     NaN
#          4 days 15:23:00               5.0                     NaN
#          4 days 15:24:00               NaN                     NaN
#          4 days 15:26:00               NaN                     NaN
#          4 days 16:23:00               NaN                    98.6
#
#                             Tidal Volume (observed)  Tidal Volume (set)  \
# patient  time
# 30000153 -1 days +23:51:00                      NaN                 NaN
#          -1 days +23:52:00                    492.0               500.0
#          -1 days +23:56:00                      NaN                 NaN
#          -1 days +23:57:00                      NaN                 NaN
#          -1 days +23:59:00                      NaN                 NaN
# ...                                             ...                 ...
# 39999810 4 days 13:24:00                        NaN                 NaN
#          4 days 15:23:00                        NaN                 NaN
#          4 days 15:24:00                        NaN                 NaN
#          4 days 15:26:00                        NaN                 NaN
#          4 days 16:23:00                        NaN                 NaN
#
#                             Tidal Volume (spontaneous)  Total PEEP Level  \
# patient  time
# 30000153 -1 days +23:51:00                         NaN               5.0
#          -1 days +23:52:00                         NaN               NaN
#          -1 days +23:56:00                         NaN               NaN
#          -1 days +23:57:00                         NaN               NaN
#          -1 days +23:59:00                         NaN               NaN
# ...                                                ...               ...
# 39999810 4 days 13:24:00                           NaN               NaN
#          4 days 15:23:00                           NaN               NaN
#          4 days 15:24:00                           NaN               NaN
#          4 days 15:26:00                           NaN               NaN
#          4 days 16:23:00                           NaN               NaN
#
#                             Ventilator Mode  Vti High  Braden Score
# patient  time
# 30000153 -1 days +23:51:00              NaN       NaN           NaN
#          -1 days +23:52:00             49.0      2.04           NaN
#          -1 days +23:56:00              NaN       NaN           NaN
#          -1 days +23:57:00              NaN       NaN           NaN
#          -1 days +23:59:00              NaN       NaN           NaN
# ...                                     ...       ...           ...
# 39999810 4 days 13:24:00                NaN       NaN           NaN
#          4 days 15:23:00                NaN       NaN           NaN
#          4 days 15:24:00                NaN       NaN           NaN
#          4 days 15:26:00                NaN       NaN           NaN
#          4 days 16:23:00                NaN       NaN           NaN
#
# [14017077 rows x 65 columns]

# %%
timeseries_summary = timeseries_processing(timeseries, labels, 0)

# %%
timeseries_summary
# Out:
#           Activity / Mobility (JH-HLM)_mean  Apnea Interval_mean  \
# patient
# 30000153                                NaN                 20.0
# 30000213                           3.500000                 40.0
# 30000484                                NaN                  NaN
# 30000646                                NaN                  NaN
# 30001148                                NaN                 20.0
# ...                                     ...                  ...
# 39999301                                NaN                  NaN
# 39999384                           2.500000                  NaN
# 39999552                                NaN                 20.0
# 39999562                           2.333333                  NaN
# 39999810                           3.177778                  NaN
#
#           Arterial Blood Pressure Alarm - High_mean  \
# patient
# 30000153                                 156.666667
# 30000213                                        NaN
# 30000484                                        NaN
# 30000646                                        NaN
# 30001148                                 106.666667
# ...                                             ...
# 39999301                                 150.000000
# 39999384                                 100.000000
# 39999552                                 143.333333
# 39999562                                        NaN
# 39999810                                        NaN
#
#           Arterial Blood Pressure Alarm - Low_mean  \
# patient
# 30000153                                 96.666667
# 30000213                                       NaN
# 30000484                                       NaN
# 30000646                                       NaN
# 30001148                                 70.000000
# ...                                            ...
# 39999301                                 90.000000
# 39999384                                 80.000000
# 39999552                                 90.000000
# 39999562                                       NaN
# 39999810                                       NaN
#
#           Arterial Blood Pressure diastolic_mean  \
# patient
# 30000153                               66.935484
# 30000213                                     NaN
# 30000484                                     NaN
# 30000646                                     NaN
# 30001148                               58.833333
# ...                                          ...
# 39999301                                     NaN
# 39999384                               49.857143
# 39999552                               62.888889
# 39999562                                     NaN
# 39999810                                     NaN
#
#           Arterial Blood Pressure mean_mean  \
# patient
# 30000153                          90.300000
# 30000213                                NaN
# 30000484                                NaN
# 30000646                                NaN
# 30001148                          73.541667
# ...                                     ...
# 39999301                                NaN
# 39999384                          87.642857
# 39999552                          83.185185
# 39999562                                NaN
# 39999810                                NaN
#
#           Arterial Blood Pressure systolic_mean  Chloride (serum)_mean  \
# patient
# 30000153                             137.387097             115.000000
# 30000213                                    NaN             100.666667
# 30000484                                    NaN             105.000000
# 30000646                                    NaN             110.571429
# 30001148                             108.291667             109.500000
# ...                                         ...                    ...
# 39999301                                    NaN             108.500000
# 39999384                             167.642857             103.000000
# 39999552                             120.407407             105.666667
# 39999562                                    NaN             102.500000
# 39999810                                    NaN             104.400000
#
#           Creatinine (serum)_mean  Current Dyspnea Assessment_mean  ...  \
# patient                                                             ...
# 30000153                 1.000000                              NaN  ...
# 30000213                 3.666667                              0.0  ...
# 30000484                 1.233333                              NaN  ...
# 30000646                 0.700000                              NaN  ...
# 30001148                 0.600000                              NaN  ...
# ...                           ...                              ...  ...
# 39999301                 1.650000                              NaN  ...
# 39999384                 2.200000                              0.0  ...
# 39999552                 0.700000                              NaN  ...
# 39999562                 0.850000                              0.0  ...
# 39999810                 1.000000                              0.0  ...
#
#           Temperature Fahrenheit_std  Tidal Volume (observed)_std  \
# patient
# 30000153                    0.950438                    78.542982
# 30000213                    0.636896                   107.637951
# 30000484                    0.907538                          NaN
# 30000646                    0.949464                          NaN
# 30001148                    1.864314                   289.206674
# ...                              ...                          ...
# 39999301                    0.479236                          NaN
# 39999384                    0.335676                          NaN
# 39999552                         NaN                   267.664591
# 39999562                    0.451422                          NaN
# 39999810                    0.367423                          NaN
#
#           Tidal Volume (set)_std  Tidal Volume (spontaneous)_std  \
# patient
# 30000153                0.000000                             NaN
# 30000213              162.388423                       25.979158
# 30000484                     NaN                             NaN
# 30000646                     NaN                             NaN
# 30001148                     NaN                             NaN
# ...                          ...                             ...
# 39999301                     NaN                             NaN
# 39999384                     NaN                             NaN
# 39999552               28.867513                             NaN
# 39999562                     NaN                             NaN
# 39999810                     NaN                             NaN
#
#           Total PEEP Level_std  Ventilator Mode_std  Vti High_std  \
# patient
# 30000153              0.000000            21.939310           0.0
# 30000213              2.903618                  NaN           0.0
# 30000484                   NaN                  NaN           NaN
# 30000646                   NaN                  NaN           NaN
# 30001148                   NaN            26.870058           0.0
# ...                        ...                  ...           ...
# 39999301                   NaN                  NaN           NaN
# 39999384                   NaN                  NaN           NaN
# 39999552                   NaN            27.135463           0.0
# 39999562                   NaN                  NaN           NaN
# 39999810                   NaN                  NaN           NaN
#
#           Braden Score_std  uniquepid_std  patienthealthsystemstayid_std
# patient
# 30000153          1.356203            0.0                            0.0
# 30000213          1.032796            0.0                            0.0
# 30000484          1.363442            0.0                            0.0
# 30000646          2.286737            0.0                            0.0
# 30001148          2.857738            0.0                            0.0
# ...                    ...            ...                            ...
# 39999301          1.500000            0.0                            0.0
# 39999384          1.732051            0.0                            0.0
# 39999552          0.000000            0.0                            0.0
# 39999562          2.368778            0.0                            0.0
# 39999810          1.763834            0.0                            0.0
#
# [76931 rows x 134 columns]

# %%
# Drop row that has all NaN values
timeseries_summary=timeseries_summary.dropna(how='all')

# %%
timeseries_summary
# Out:
#           Activity / Mobility (JH-HLM)_mean  Apnea Interval_mean  \
# patient
# 30000153                                NaN                 20.0
# 30000213                           3.500000                 40.0
# 30000484                                NaN                  NaN
# 30000646                                NaN                  NaN
# 30001148                                NaN                 20.0
# ...                                     ...                  ...
# 39999301                                NaN                  NaN
# 39999384                           2.500000                  NaN
# 39999552                                NaN                 20.0
# 39999562                           2.333333                  NaN
# 39999810                           3.177778                  NaN
#
#           Arterial Blood Pressure Alarm - High_mean  \
# patient
# 30000153                                 156.666667
# 30000213                                        NaN
# 30000484                                        NaN
# 30000646                                        NaN
# 30001148                                 106.666667
# ...                                             ...
# 39999301                                 150.000000
# 39999384                                 100.000000
# 39999552                                 143.333333
# 39999562                                        NaN
# 39999810                                        NaN
#
#           Arterial Blood Pressure Alarm - Low_mean  \
# patient
# 30000153                                 96.666667
# 30000213                                       NaN
# 30000484                                       NaN
# 30000646                                       NaN
# 30001148                                 70.000000
# ...                                            ...
# 39999301                                 90.000000
# 39999384                                 80.000000
# 39999552                                 90.000000
# 39999562                                       NaN
# 39999810                                       NaN
#
#           Arterial Blood Pressure diastolic_mean  \
# patient
# 30000153                               66.935484
# 30000213                                     NaN
# 30000484                                     NaN
# 30000646                                     NaN
# 30001148                               58.833333
# ...                                          ...
# 39999301                                     NaN
# 39999384                               49.857143
# 39999552                               62.888889
# 39999562                                     NaN
# 39999810                                     NaN
#
#           Arterial Blood Pressure mean_mean  \
# patient
# 30000153                          90.300000
# 30000213                                NaN
# 30000484                                NaN
# 30000646                                NaN
# 30001148                          73.541667
# ...                                     ...
# 39999301                                NaN
# 39999384                          87.642857
# 39999552                          83.185185
# 39999562                                NaN
# 39999810                                NaN
#
#           Arterial Blood Pressure systolic_mean  Chloride (serum)_mean  \
# patient
# 30000153                             137.387097             115.000000
# 30000213                                    NaN             100.666667
# 30000484                                    NaN             105.000000
# 30000646                                    NaN             110.571429
# 30001148                             108.291667             109.500000
# ...                                         ...                    ...
# 39999301                                    NaN             108.500000
# 39999384                             167.642857             103.000000
# 39999552                             120.407407             105.666667
# 39999562                                    NaN             102.500000
# 39999810                                    NaN             104.400000
#
#           Creatinine (serum)_mean  Current Dyspnea Assessment_mean  ...  \
# patient                                                             ...
# 30000153                 1.000000                              NaN  ...
# 30000213                 3.666667                              0.0  ...
# 30000484                 1.233333                              NaN  ...
# 30000646                 0.700000                              NaN  ...
# 30001148                 0.600000                              NaN  ...
# ...                           ...                              ...  ...
# 39999301                 1.650000                              NaN  ...
# 39999384                 2.200000                              0.0  ...
# 39999552                 0.700000                              NaN  ...
# 39999562                 0.850000                              0.0  ...
# 39999810                 1.000000                              0.0  ...
#
#           Temperature Fahrenheit_std  Tidal Volume (observed)_std  \
# patient
# 30000153                    0.950438                    78.542982
# 30000213                    0.636896                   107.637951
# 30000484                    0.907538                          NaN
# 30000646                    0.949464                          NaN
# 30001148                    1.864314                   289.206674
# ...                              ...                          ...
# 39999301                    0.479236                          NaN
# 39999384                    0.335676                          NaN
# 39999552                         NaN                   267.664591
# 39999562                    0.451422                          NaN
# 39999810                    0.367423                          NaN
#
#           Tidal Volume (set)_std  Tidal Volume (spontaneous)_std  \
# patient
# 30000153                0.000000                             NaN
# 30000213              162.388423                       25.979158
# 30000484                     NaN                             NaN
# 30000646                     NaN                             NaN
# 30001148                     NaN                             NaN
# ...                          ...                             ...
# 39999301                     NaN                             NaN
# 39999384                     NaN                             NaN
# 39999552               28.867513                             NaN
# 39999562                     NaN                             NaN
# 39999810                     NaN                             NaN
#
#           Total PEEP Level_std  Ventilator Mode_std  Vti High_std  \
# patient
# 30000153              0.000000            21.939310           0.0
# 30000213              2.903618                  NaN           0.0
# 30000484                   NaN                  NaN           NaN
# 30000646                   NaN                  NaN           NaN
# 30001148                   NaN            26.870058           0.0
# ...                        ...                  ...           ...
# 39999301                   NaN                  NaN           NaN
# 39999384                   NaN                  NaN           NaN
# 39999552                   NaN            27.135463           0.0
# 39999562                   NaN                  NaN           NaN
# 39999810                   NaN                  NaN           NaN
#
#           Braden Score_std  uniquepid_std  patienthealthsystemstayid_std
# patient
# 30000153          1.356203            0.0                            0.0
# 30000213          1.032796            0.0                            0.0
# 30000484          1.363442            0.0                            0.0
# 30000646          2.286737            0.0                            0.0
# 30001148          2.857738            0.0                            0.0
# ...                    ...            ...                            ...
# 39999301          1.500000            0.0                            0.0
# 39999384          1.732051            0.0                            0.0
# 39999552          0.000000            0.0                            0.0
# 39999562          2.368778            0.0                            0.0
# 39999810          1.763834            0.0                            0.0
#
# [76931 rows x 134 columns]

# %% [markdown]
# # Lab Measurements

# %%
timeseries_lab = pd.read_csv('preprocessed_timeseries_lab.csv', index_col=['patient', 'time'])

# %%
timeseries_lab_summary = timeseries_processing(timeseries_lab, labels, 0)

# %%
timeseries_lab_summary
# Out:
#           Alanine Aminotransferase (ALT)_mean  Alkaline Phosphatase_mean  \
# patient
# 30000153                            15.000000                        NaN
# 30000213                            12.000000                  97.000000
# 30000484                            12.333333                  75.333333
# 30000646                            22.000000                  97.000000
# 30001148                             9.000000                  94.000000
# ...                                       ...                        ...
# 39999301                            13.000000                  59.000000
# 39999384                                  NaN                        NaN
# 39999552                                  NaN                        NaN
# 39999562                                  NaN                        NaN
# 39999810                            44.000000                  73.000000
#
#           Anion Gap_mean  Asparate Aminotransferase (AST)_mean  \
# patient
# 30000153       12.000000                             62.000000
# 30000213       15.666667                             19.000000
# 30000484       10.000000                             34.333333
# 30000646       12.000000                             19.000000
# 30001148       10.500000                             15.000000
# ...                  ...                                   ...
# 39999301       13.500000                             18.000000
# 39999384       16.000000                                   NaN
# 39999552       11.500000                                   NaN
# 39999562       11.333333                                   NaN
# 39999810       15.400000                             38.000000
#
#           Base Excess_mean  Bicarbonate_mean  Bilirubin, Total_mean  \
# patient
# 30000153         -3.333333         21.000000                    NaN
# 30000213          0.500000         23.333333               0.300000
# 30000484          1.000000         27.666667               0.333333
# 30000646         -1.000000         22.125000               0.700000
# 30001148          2.444444         27.666667               0.500000
# ...                    ...               ...                    ...
# 39999301         -2.666667         23.500000               0.400000
# 39999384               NaN         24.000000                    NaN
# 39999552          3.500000         26.000000                    NaN
# 39999562               NaN         24.333333                    NaN
# 39999810               NaN         23.400000               0.800000
#
#           Calcium, Total_mean  Calculated Total CO2_mean  Chloride_mean  ...  \
# patient                                                                  ...
# 30000153             7.700000                  22.666667     115.000000  ...
# 30000213             8.333333                  27.000000     100.666667  ...
# 30000484             8.133333                  33.000000     105.000000  ...
# 30000646             7.625000                  21.000000     109.500000  ...
# 30001148                  NaN                  28.111111     106.666667  ...
# ...                       ...                        ...            ...  ...
# 39999301             8.800000                  22.666667     108.500000  ...
# 39999384             8.600000                        NaN     103.000000  ...
# 39999552             8.800000                  27.166667     105.666667  ...
# 39999562             8.500000                        NaN     103.666667  ...
# 39999810             8.880000                        NaN     104.400000  ...
#
#           Sodium_std  Sodium, Whole Blood_std  Temperature_std  \
# patient
# 30000153    2.121320                 0.707107              NaN
# 30000213    0.577350                      NaN              NaN
# 30000484    2.000000                      NaN              NaN
# 30000646    1.846812                      NaN              NaN
# 30001148    0.707107                 2.081666              NaN
# ...              ...                      ...              ...
# 39999301    0.000000                      NaN              NaN
# 39999384         NaN                      NaN              NaN
# 39999552    2.081666                 1.527525              NaN
# 39999562    3.055050                      NaN              NaN
# 39999810    1.483240                      NaN              NaN
#
#           Urea Nitrogen_std  White Blood Cells_std  pCO2_std    pH_std  \
# patient
# 30000153           0.000000               1.272792  1.732051  0.005774
# 30000213           0.577350                    NaN  4.949747  1.100409
# 30000484           5.507571               3.137409       NaN  0.510523
# 30000646           1.927248               0.988144       NaN  0.028284
# 30001148           2.081666               2.458997  5.622376  0.147124
# ...                     ...                    ...       ...       ...
# 39999301           3.535534               0.850490  5.507571  0.045092
# 39999384                NaN               0.424264       NaN       NaN
# 39999552           0.000000               0.750555  2.786874  0.293762
# 39999562           0.577350               0.351188       NaN       NaN
# 39999810           1.303840               0.793200       NaN       NaN
#
#              pO2_std  uniquepid_std  patienthealthsystemstayid_std
# patient
# 30000153   26.153394            0.0                            0.0
# 30000213    4.949747            0.0                            0.0
# 30000484         NaN            0.0                            0.0
# 30000646         NaN            0.0                            0.0
# 30001148   92.030037            0.0                            0.0
# ...              ...            ...                            ...
# 39999301  143.238728            0.0                            0.0
# 39999384         NaN            0.0                            0.0
# 39999552  118.390315            0.0                            0.0
# 39999562         NaN            0.0                            0.0
# 39999810         NaN            0.0                            0.0
#
# [75868 rows x 90 columns]

# %% [markdown]
# # Static Features

# %%
flats = pd.read_csv('preprocessed_flat.csv', index_col='patient')

# %%
flats = flats.drop(['nullheight'], axis=1)

# %%
flats
# Out:
#           gender  age  height      weight  hour      eyes     motor  \
# patient
# 30000153       1   61     0.0   70.000000    12  3.666667  5.933333
# 30000213       1   66   160.0   84.700000     5  3.666667  5.666667
# 30000484       1   92   163.0   68.500000    17  3.866667  4.933333
# 30000646       1   44     0.0    4.000000     1  6.000000  5.000000
# 30001148       1   68   183.0   65.700000    11  3.200000  5.000000
# ...          ...  ...     ...         ...   ...       ...       ...
# 39999301       1   77   170.0  107.700000    15  4.000000  6.000000
# 39999384       0   81     0.0   67.000000    19  4.000000  6.000000
# 39999552       0   72   173.0   64.500000    14  3.000000  4.750000
# 39999562       1   71     0.0   62.000000    17  4.000000  6.000000
# 39999810       1   55     0.0    2.923077     0  6.000000  5.000000
#
#               verbal  ethnicity_BLACK/AFRICAN AMERICAN  ethnicity_OTHER  ...  \
# patient                                                                  ...
# 30000153    3.800000                                 0                0  ...
# 30000213    3.000000                                 0                0  ...
# 30000484    3.066667                                 0                0  ...
# 30000646  170.000000                                 0                0  ...
# 30001148    4.200000                                 0                0  ...
# ...              ...                               ...              ...  ...
# 39999301    5.000000                                 1                0  ...
# 39999384    5.000000                                 0                0  ...
# 39999552    4.000000                                 0                0  ...
# 39999562    5.000000                                 0                0  ...
# 39999810    0.000000                                 0                0  ...
#
#           admission_location_EMERGENCY ROOM  \
# patient
# 30000153                                  1
# 30000213                                  0
# 30000484                                  1
# 30000646                                  1
# 30001148                                  0
# ...                                     ...
# 39999301                                  1
# 39999384                                  0
# 39999552                                  0
# 39999562                                  0
# 39999810                                  0
#
#           admission_location_PHYSICIAN REFERRAL  \
# patient
# 30000153                                      0
# 30000213                                      1
# 30000484                                      0
# 30000646                                      0
# 30001148                                      0
# ...                                         ...
# 39999301                                      0
# 39999384                                      1
# 39999552                                      1
# 39999562                                      1
# 39999810                                      0
#
#           admission_location_PROCEDURE SITE  \
# patient
# 30000153                                  0
# 30000213                                  0
# 30000484                                  0
# 30000646                                  0
# 30001148                                  0
# ...                                     ...
# 39999301                                  0
# 39999384                                  0
# 39999552                                  0
# 39999562                                  0
# 39999810                                  0
#
#           admission_location_TRANSFER FROM HOSPITAL  \
# patient
# 30000153                                          0
# 30000213                                          0
# 30000484                                          0
# 30000646                                          0
# 30001148                                          1
# ...                                             ...
# 39999301                                          0
# 39999384                                          0
# 39999552                                          0
# 39999562                                          0
# 39999810                                          1
#
#           admission_location_TRANSFER FROM SKILLED NURSING FACILITY  \
# patient
# 30000153                                                  0
# 30000213                                                  0
# 30000484                                                  0
# 30000646                                                  0
# 30001148                                                  0
# ...                                                     ...
# 39999301                                                  0
# 39999384                                                  0
# 39999552                                                  0
# 39999562                                                  0
# 39999810                                                  0
#
#           admission_location_WALK-IN/SELF REFERRAL  admission_location_misc  \
# patient
# 30000153                                         0                        0
# 30000213                                         0                        0
# 30000484                                         0                        0
# 30000646                                         0                        0
# 30001148                                         0                        0
# ...                                            ...                      ...
# 39999301                                         0                        0
# 39999384                                         0                        0
# 39999552                                         0                        0
# 39999562                                         0                        0
# 39999810                                         0                        0
#
#           insurance_Medicaid  insurance_Medicare  insurance_Other
# patient
# 30000153                   0                   0                1
# 30000213                   0                   1                0
# 30000484                   0                   1                0
# 30000646                   1                   0                0
# 30001148                   0                   0                1
# ...                      ...                 ...              ...
# 39999301                   0                   0                1
# 39999384                   0                   1                0
# 39999552                   0                   0                1
# 39999562                   0                   1                0
# 39999810                   0                   0                1
#
# [76938 rows x 33 columns]

# %%
labels.merge(timeseries_lab_summary, left_index=True, right_index=True)
# Out:
#           uniquepid  patienthealthsystemstayid  actualhospitalmortality  \
# patient
# 30000153   12466550                   23998182                        0
# 30000213   13180007                   27543152                        0
# 30000484   18421337                   22413411                        0
# 30000646   12207593                   22795209                        1
# 30001148   12980335                   23552849                        0
# ...             ...                        ...                      ...
# 39999301   16180713                   20178444                        1
# 39999384   15498623                   27161460                        0
# 39999552   11256534                   26910235                        0
# 39999562   15403458                   25335698                        0
# 39999810   17840864                   22695803                        0
#
#           actualiculos   patient  Alanine Aminotransferase (ALT)_mean  \
# patient
# 30000153   2357.166667  30000153                            15.000000
# 30000213   2354.800000  30000213                            12.000000
# 30000484   3569.600000  30000484                            12.333333
# 30000646   6764.433333  30000646                            22.000000
# 30001148   1634.583333  30001148                             9.000000
# ...                ...       ...                                  ...
# 39999301   1651.550000  39999301                            13.000000
# 39999384   1837.100000  39999384                                  NaN
# 39999552   1681.366667  39999552                                  NaN
# 39999562   7194.666667  39999562                                  NaN
# 39999810   6830.950000  39999810                            44.000000
#
#           Alkaline Phosphatase_mean  Anion Gap_mean  \
# patient
# 30000153                        NaN       12.000000
# 30000213                  97.000000       15.666667
# 30000484                  75.333333       10.000000
# 30000646                  97.000000       12.000000
# 30001148                  94.000000       10.500000
# ...                             ...             ...
# 39999301                  59.000000       13.500000
# 39999384                        NaN       16.000000
# 39999552                        NaN       11.500000
# 39999562                        NaN       11.333333
# 39999810                  73.000000       15.400000
#
#           Asparate Aminotransferase (AST)_mean  Base Excess_mean  ...  \
# patient                                                           ...
# 30000153                             62.000000         -3.333333  ...
# 30000213                             19.000000          0.500000  ...
# 30000484                             34.333333          1.000000  ...
# 30000646                             19.000000         -1.000000  ...
# 30001148                             15.000000          2.444444  ...
# ...                                        ...               ...  ...
# 39999301                             18.000000         -2.666667  ...
# 39999384                                   NaN               NaN  ...
# 39999552                                   NaN          3.500000  ...
# 39999562                                   NaN               NaN  ...
# 39999810                             38.000000               NaN  ...
#
#           Sodium_std  Sodium, Whole Blood_std  Temperature_std  \
# patient
# 30000153    2.121320                 0.707107              NaN
# 30000213    0.577350                      NaN              NaN
# 30000484    2.000000                      NaN              NaN
# 30000646    1.846812                      NaN              NaN
# 30001148    0.707107                 2.081666              NaN
# ...              ...                      ...              ...
# 39999301    0.000000                      NaN              NaN
# 39999384         NaN                      NaN              NaN
# 39999552    2.081666                 1.527525              NaN
# 39999562    3.055050                      NaN              NaN
# 39999810    1.483240                      NaN              NaN
#
#           Urea Nitrogen_std  White Blood Cells_std  pCO2_std    pH_std  \
# patient
# 30000153           0.000000               1.272792  1.732051  0.005774
# 30000213           0.577350                    NaN  4.949747  1.100409
# 30000484           5.507571               3.137409       NaN  0.510523
# 30000646           1.927248               0.988144       NaN  0.028284
# 30001148           2.081666               2.458997  5.622376  0.147124
# ...                     ...                    ...       ...       ...
# 39999301           3.535534               0.850490  5.507571  0.045092
# 39999384                NaN               0.424264       NaN       NaN
# 39999552           0.000000               0.750555  2.786874  0.293762
# 39999562           0.577350               0.351188       NaN       NaN
# 39999810           1.303840               0.793200       NaN       NaN
#
#              pO2_std  uniquepid_std  patienthealthsystemstayid_std
# patient
# 30000153   26.153394            0.0                            0.0
# 30000213    4.949747            0.0                            0.0
# 30000484         NaN            0.0                            0.0
# 30000646         NaN            0.0                            0.0
# 30001148   92.030037            0.0                            0.0
# ...              ...            ...                            ...
# 39999301  143.238728            0.0                            0.0
# 39999384         NaN            0.0                            0.0
# 39999552  118.390315            0.0                            0.0
# 39999562         NaN            0.0                            0.0
# 39999810         NaN            0.0                            0.0
#
# [75868 rows x 95 columns]

# %%
labels.merge(timeseries_summary, left_index=True, right_index=True)
# Out:
#           uniquepid  patienthealthsystemstayid  actualhospitalmortality  \
# patient
# 30000153   12466550                   23998182                        0
# 30000213   13180007                   27543152                        0
# 30000484   18421337                   22413411                        0
# 30000646   12207593                   22795209                        1
# 30001148   12980335                   23552849                        0
# ...             ...                        ...                      ...
# 39999301   16180713                   20178444                        1
# 39999384   15498623                   27161460                        0
# 39999552   11256534                   26910235                        0
# 39999562   15403458                   25335698                        0
# 39999810   17840864                   22695803                        0
#
#           actualiculos   patient  Activity / Mobility (JH-HLM)_mean  \
# patient
# 30000153   2357.166667  30000153                                NaN
# 30000213   2354.800000  30000213                           3.500000
# 30000484   3569.600000  30000484                                NaN
# 30000646   6764.433333  30000646                                NaN
# 30001148   1634.583333  30001148                                NaN
# ...                ...       ...                                ...
# 39999301   1651.550000  39999301                                NaN
# 39999384   1837.100000  39999384                           2.500000
# 39999552   1681.366667  39999552                                NaN
# 39999562   7194.666667  39999562                           2.333333
# 39999810   6830.950000  39999810                           3.177778
#
#           Apnea Interval_mean  Arterial Blood Pressure Alarm - High_mean  \
# patient
# 30000153                 20.0                                 156.666667
# 30000213                 40.0                                        NaN
# 30000484                  NaN                                        NaN
# 30000646                  NaN                                        NaN
# 30001148                 20.0                                 106.666667
# ...                       ...                                        ...
# 39999301                  NaN                                 150.000000
# 39999384                  NaN                                 100.000000
# 39999552                 20.0                                 143.333333
# 39999562                  NaN                                        NaN
# 39999810                  NaN                                        NaN
#
#           Arterial Blood Pressure Alarm - Low_mean  \
# patient
# 30000153                                 96.666667
# 30000213                                       NaN
# 30000484                                       NaN
# 30000646                                       NaN
# 30001148                                 70.000000
# ...                                            ...
# 39999301                                 90.000000
# 39999384                                 80.000000
# 39999552                                 90.000000
# 39999562                                       NaN
# 39999810                                       NaN
#
#           Arterial Blood Pressure diastolic_mean  ...  \
# patient                                           ...
# 30000153                               66.935484  ...
# 30000213                                     NaN  ...
# 30000484                                     NaN  ...
# 30000646                                     NaN  ...
# 30001148                               58.833333  ...
# ...                                          ...  ...
# 39999301                                     NaN  ...
# 39999384                               49.857143  ...
# 39999552                               62.888889  ...
# 39999562                                     NaN  ...
# 39999810                                     NaN  ...
#
#           Temperature Fahrenheit_std  Tidal Volume (observed)_std  \
# patient
# 30000153                    0.950438                    78.542982
# 30000213                    0.636896                   107.637951
# 30000484                    0.907538                          NaN
# 30000646                    0.949464                          NaN
# 30001148                    1.864314                   289.206674
# ...                              ...                          ...
# 39999301                    0.479236                          NaN
# 39999384                    0.335676                          NaN
# 39999552                         NaN                   267.664591
# 39999562                    0.451422                          NaN
# 39999810                    0.367423                          NaN
#
#           Tidal Volume (set)_std  Tidal Volume (spontaneous)_std  \
# patient
# 30000153                0.000000                             NaN
# 30000213              162.388423                       25.979158
# 30000484                     NaN                             NaN
# 30000646                     NaN                             NaN
# 30001148                     NaN                             NaN
# ...                          ...                             ...
# 39999301                     NaN                             NaN
# 39999384                     NaN                             NaN
# 39999552               28.867513                             NaN
# 39999562                     NaN                             NaN
# 39999810                     NaN                             NaN
#
#           Total PEEP Level_std  Ventilator Mode_std  Vti High_std  \
# patient
# 30000153              0.000000            21.939310           0.0
# 30000213              2.903618                  NaN           0.0
# 30000484                   NaN                  NaN           NaN
# 30000646                   NaN                  NaN           NaN
# 30001148                   NaN            26.870058           0.0
# ...                        ...                  ...           ...
# 39999301                   NaN                  NaN           NaN
# 39999384                   NaN                  NaN           NaN
# 39999552                   NaN            27.135463           0.0
# 39999562                   NaN                  NaN           NaN
# 39999810                   NaN                  NaN           NaN
#
#           Braden Score_std  uniquepid_std  patienthealthsystemstayid_std
# patient
# 30000153          1.356203            0.0                            0.0
# 30000213          1.032796            0.0                            0.0
# 30000484          1.363442            0.0                            0.0
# 30000646          2.286737            0.0                            0.0
# 30001148          2.857738            0.0                            0.0
# ...                    ...            ...                            ...
# 39999301          1.500000            0.0                            0.0
# 39999384          1.732051            0.0                            0.0
# 39999552          0.000000            0.0                            0.0
# 39999562          2.368778            0.0                            0.0
# 39999810          1.763834            0.0                            0.0
#
# [76931 rows x 139 columns]

# %% [markdown]
# # For Death Prediction

# %%
final = ED_linked.merge(flats, left_index=True, right_index=True)
print(final.shape[0])
final = final.merge(timeseries_lab_summary, left_index=True, right_index=True)
print(final.shape[0])
final = final.merge(timeseries_summary, left_index=True, right_index=True)
print(final.shape[0])
# Out:
# 1463
# 1433
# 1433

# %%
final
final = final.drop(columns=['uniquepid_mean_x', 'patienthealthsystemstayid_mean_x', 'uniquepid_std_x', 'patienthealthsystemstayid_std_x',
                           'uniquepid_mean_y', 'patienthealthsystemstayid_mean_y', 'uniquepid_std_y', 'patienthealthsystemstayid_std_y'])
final = final.dropna(thresh=final.shape[0]*0.4,how='all',axis=1)

# %%
final
# Out:
#             actualhospitalmortality  actualiculos  gender  age  height  \
# patient
# 30009596.0                      0.0   2140.566667       0   77     0.0
# 30016794.0                      0.0   2996.666667       1   70     0.0
# 30018045.0                      0.0   6942.716667       1   57   188.0
# 30030569.0                      0.0   2345.000000       0   91     0.0
# 30032853.0                      0.0   3162.150000       1   55   188.0
# ...                             ...           ...     ...  ...     ...
# 39964005.0                      1.0   3371.050000       0   68   165.0
# 39965733.0                      0.0  17183.550000       1   75   167.0
# 39971339.0                      0.0   7596.250000       0   83   157.0
# 39977970.0                      1.0   2716.716667       1   91     0.0
# 39990055.0                      0.0   4039.966667       0   91   165.0
#
#             weight  hour      eyes     motor    verbal  ...  \
# patient                                                 ...
# 30009596.0    72.0     7  4.000000  6.000000  5.000000  ...
# 30016794.0    62.9    18  3.800000  5.933333  5.000000  ...
# 30018045.0   102.5    21  4.000000  6.000000  5.000000  ...
# 30030569.0    55.9    22  3.280000  6.000000  4.280000  ...
# 30032853.0   125.0    12  3.625000  5.375000  4.500000  ...
# ...            ...   ...       ...       ...       ...  ...
# 39964005.0    76.5     1  1.428571  4.357143  1.000000  ...
# 39965733.0    64.1    20  3.660714  5.875000  2.928571  ...
# 39971339.0    63.0    10  3.769231  5.615385  4.384615  ...
# 39977970.0    75.8    21  3.666667  4.916667  1.083333  ...
# 39990055.0    64.6    23  2.294118  4.941176  1.176471  ...
#
#             Respiratory Rate_std  Richmond-RAS Scale_std  \
# patient
# 30009596.0              2.752621                0.000000
# 30016794.0              5.188127                0.000000
# 30018045.0              4.541570                0.510754
# 30030569.0              5.631755                0.447214
# 30032853.0              4.182711                1.802776
# ...                          ...                     ...
# 39964005.0              4.858897                1.164965
# 39965733.0              5.175042                0.760279
# 39971339.0              3.103539                1.165287
# 39977970.0              6.443721                0.000000
# 39990055.0              4.327338                2.113726
#
#             Secondary diagnosis_std  Sodium (serum)_std  Strength L Arm_std  \
# patient
# 30009596.0                      NaN                 NaN            0.000000
# 30016794.0                      0.0            0.577350            0.510418
# 30018045.0                      0.0            3.361547            0.000000
# 30030569.0                      NaN                 NaN            0.403113
# 30032853.0                      0.0            1.861899            0.516398
# ...                             ...                 ...                 ...
# 39964005.0                      0.0           11.430952            0.000000
# 39965733.0                      0.0            5.910484            0.429415
# 39971339.0                      0.0            2.439750            0.408248
# 39977970.0                      0.0                 NaN            1.133893
# 39990055.0                      0.0            2.236068                 NaN
#
#             Strength L Leg_std  Strength R Arm_std  Strength R Leg_std  \
# patient
# 30009596.0            0.000000            0.000000            0.000000
# 30016794.0            0.000000            0.000000            0.000000
# 30018045.0            0.000000            0.000000            0.000000
# 30030569.0            0.000000            0.341565            0.000000
# 30032853.0            0.516398            0.516398            0.516398
# ...                        ...                 ...                 ...
# 39964005.0            0.000000            0.000000            0.000000
# 39965733.0            0.753244            0.429415            0.753244
# 39971339.0            0.688737            0.408248            0.688737
# 39977970.0            1.133893            0.899735            0.786796
# 39990055.0                 NaN                 NaN                 NaN
#
#             Temperature Fahrenheit_std  Braden Score_std
# patient
# 30009596.0                    0.070711               NaN
# 30016794.0                    0.288675               NaN
# 30018045.0                    0.420178          1.290994
# 30030569.0                    1.005982          0.707107
# 30032853.0                    0.309839          2.886751
# ...                                ...               ...
# 39964005.0                    0.684769          0.516398
# 39965733.0                    0.424300          1.627882
# 39971339.0                    0.618166          1.804036
# 39977970.0                    0.230217          1.414214
# 39990055.0                    0.453900          0.899735
#
# [1143 rows x 175 columns]

# %%
final['actualhospitalmortality'].value_counts()
# Out:
# 0.0    1006
# 1.0     137
# Name: actualhospitalmortality, dtype: int64

# %%
list(final.columns)
# Out:
# ['actualhospitalmortality',
#  'actualiculos',
#  'gender',
#  'age',
#  'height',
#  'weight',
#  'hour',
#  'eyes',
#  'motor',
#  'verbal',
#  'ethnicity_BLACK/AFRICAN AMERICAN',
#  'ethnicity_OTHER',
#  'ethnicity_UNKNOWN',
#  'ethnicity_WHITE',
#  'ethnicity_WHITE - OTHER EUROPEAN',
#  'ethnicity_misc',
#  'first_careunit_Cardiac Vascular Intensive Care Unit (CVICU)',
#  'first_careunit_Coronary Care Unit (CCU)',
#  'first_careunit_Medical Intensive Care Unit (MICU)',
#  'first_careunit_Medical/Surgical Intensive Care Unit (MICU/SICU)',
#  'first_careunit_Neuro Intermediate',
#  'first_careunit_Neuro Stepdown',
#  'first_careunit_Neuro Surgical Intensive Care Unit (Neuro SICU)',
#  'first_careunit_Surgical Intensive Care Unit (SICU)',
#  'first_careunit_Trauma SICU (TSICU)',
#  'admission_location_EMERGENCY ROOM',
#  'admission_location_PHYSICIAN REFERRAL',
#  'admission_location_PROCEDURE SITE',
#  'admission_location_TRANSFER FROM HOSPITAL',
#  'admission_location_TRANSFER FROM SKILLED NURSING FACILITY',
#  'admission_location_WALK-IN/SELF REFERRAL',
#  'admission_location_misc',
#  'insurance_Medicaid',
#  'insurance_Medicare',
#  'insurance_Other',
#  'Alanine Aminotransferase (ALT)_mean',
#  'Alkaline Phosphatase_mean',
#  'Anion Gap_mean',
#  'Asparate Aminotransferase (AST)_mean',
#  'Base Excess_mean',
#  'Bicarbonate_mean',
#  'Bilirubin, Total_mean',
#  'Calcium, Total_mean',
#  'Calculated Total CO2_mean',
#  'Chloride_mean',
#  'Creatinine_mean',
#  'Glucose_mean',
#  'H_mean',
#  'Hematocrit_mean',
#  'Hemoglobin_mean',
#  'I_mean',
#  'INR(PT)_mean',
#  'L_mean',
#  'Lactate_mean',
#  'MCH_mean',
#  'MCHC_mean',
#  'MCV_mean',
#  'Magnesium_mean',
#  'PT_mean',
#  'PTT_mean',
#  'Phosphate_mean',
#  'Platelet Count_mean',
#  'Potassium_mean',
#  'RDW_mean',
#  'RDW-SD_mean',
#  'Red Blood Cells_mean',
#  'Sodium_mean',
#  'Urea Nitrogen_mean',
#  'White Blood Cells_mean',
#  'pCO2_mean',
#  'pH_mean',
#  'pO2_mean',
#  'Anion Gap_std',
#  'Bicarbonate_std',
#  'Calcium, Total_std',
#  'Chloride_std',
#  'Creatinine_std',
#  'Glucose_std',
#  'H_std',
#  'Hematocrit_std',
#  'Hemoglobin_std',
#  'I_std',
#  'INR(PT)_std',
#  'L_std',
#  'MCH_std',
#  'MCHC_std',
#  'MCV_std',
#  'Magnesium_std',
#  'PT_std',
#  'PTT_std',
#  'Phosphate_std',
#  'Platelet Count_std',
#  'Potassium_std',
#  'RDW_std',
#  'RDW-SD_std',
#  'Red Blood Cells_std',
#  'Sodium_std',
#  'Urea Nitrogen_std',
#  'White Blood Cells_std',
#  'pH_std',
#  'Activity / Mobility (JH-HLM)_mean',
#  'Chloride (serum)_mean',
#  'Creatinine (serum)_mean',
#  'Current Dyspnea Assessment_mean',
#  'Daily Weight_mean',
#  'GCS - Eye Opening_mean',
#  'GCS - Motor Response_mean',
#  'GCS - Verbal Response_mean',
#  'Glucose (serum)_mean',
#  'Glucose finger stick (range 70-100)_mean',
#  'Heart Rate_mean',
#  'Heart Rate Alarm - Low_mean',
#  'Heart rate Alarm - High_mean',
#  'Hematocrit (serum)_mean',
#  'Non Invasive Blood Pressure diastolic_mean',
#  'Non Invasive Blood Pressure mean_mean',
#  'Non Invasive Blood Pressure systolic_mean',
#  'Non-Invasive Blood Pressure Alarm - High_mean',
#  'Non-Invasive Blood Pressure Alarm - Low_mean',
#  'O2 Flow_mean',
#  'O2 Saturation Pulseoxymetry Alarm - Low_mean',
#  'O2 saturation pulseoxymetry_mean',
#  'Pain Level_mean',
#  'Pain Level Response_mean',
#  'Phosphorous_mean',
#  'Potassium (serum)_mean',
#  'Resp Alarm - High_mean',
#  'Resp Alarm - Low_mean',
#  'Respiratory Rate_mean',
#  'Richmond-RAS Scale_mean',
#  'Secondary diagnosis_mean',
#  'Sodium (serum)_mean',
#  'Strength L Arm_mean',
#  'Strength L Leg_mean',
#  'Strength R Arm_mean',
#  'Strength R Leg_mean',
#  'Temperature Fahrenheit_mean',
#  'Braden Score_mean',
#  'Activity / Mobility (JH-HLM)_std',
#  'Chloride (serum)_std',
#  'Creatinine (serum)_std',
#  'Current Dyspnea Assessment_std',
#  'GCS - Eye Opening_std',
#  'GCS - Motor Response_std',
#  'GCS - Verbal Response_std',
#  'Glucose (serum)_std',
#  'Glucose finger stick (range 70-100)_std',
#  'Heart Rate_std',
#  'Heart Rate Alarm - Low_std',
#  'Heart rate Alarm - High_std',
#  'Hematocrit (serum)_std',
#  'Non Invasive Blood Pressure diastolic_std',
#  'Non Invasive Blood Pressure mean_std',
#  'Non Invasive Blood Pressure systolic_std',
#  'Non-Invasive Blood Pressure Alarm - High_std',
#  'Non-Invasive Blood Pressure Alarm - Low_std',
#  'O2 Flow_std',
#  'O2 Saturation Pulseoxymetry Alarm - Low_std',
#  'O2 saturation pulseoxymetry_std',
#  'Pain Level_std',
#  'Pain Level Response_std',
#  'Phosphorous_std',
#  'Potassium (serum)_std',
#  'Resp Alarm - High_std',
#  'Resp Alarm - Low_std',
#  'Respiratory Rate_std',
#  'Richmond-RAS Scale_std',
#  'Secondary diagnosis_std',
#  'Sodium (serum)_std',
#  'Strength L Arm_std',
#  'Strength L Leg_std',
#  'Strength R Arm_std',
#  'Strength R Leg_std',
#  'Temperature Fahrenheit_std',
#  'Braden Score_std']

# %%
from collections import Counter
[k for k,v in Counter(list(final.columns)).items() if v>1]
# Out:
# []

# %%
pd.set_option('display.max_columns', 1000)  # or 1000
pd.set_option('display.max_rows', 1000)  # or 1000
pd.set_option('display.max_colwidth', 1000)  # or 199

# Missing values per feature
final.isnull().sum(axis = 0)/1410*100
# Out:
# actualhospitalmortality                                             0.000000
# actualiculos                                                        0.000000
# gender                                                              0.000000
# age                                                                 0.000000
# height                                                              0.000000
# weight                                                              0.000000
# hour                                                                0.000000
# eyes                                                                0.000000
# motor                                                               0.000000
# verbal                                                              0.000000
# ethnicity_BLACK/AFRICAN AMERICAN                                    0.000000
# ethnicity_OTHER                                                     0.000000
# ethnicity_UNKNOWN                                                   0.000000
# ethnicity_WHITE                                                     0.000000
# ethnicity_WHITE - OTHER EUROPEAN                                    0.000000
# ethnicity_misc                                                      0.000000
# first_careunit_Cardiac Vascular Intensive Care Unit (CVICU)         0.000000
# first_careunit_Coronary Care Unit (CCU)                             0.000000
# first_careunit_Medical Intensive Care Unit (MICU)                   0.000000
# first_careunit_Medical/Surgical Intensive Care Unit (MICU/SICU)     0.000000
# first_careunit_Neuro Intermediate                                   0.000000
# first_careunit_Neuro Stepdown                                       0.000000
# first_careunit_Neuro Surgical Intensive Care Unit (Neuro SICU)      0.000000
# first_careunit_Surgical Intensive Care Unit (SICU)                  0.000000
# first_careunit_Trauma SICU (TSICU)                                  0.000000
# admission_location_EMERGENCY ROOM                                   0.000000
# admission_location_PHYSICIAN REFERRAL                               0.000000
# admission_location_PROCEDURE SITE                                   0.000000
# admission_location_TRANSFER FROM HOSPITAL                           0.000000
# admission_location_TRANSFER FROM SKILLED NURSING FACILITY           0.000000
# admission_location_WALK-IN/SELF REFERRAL                            0.000000
# admission_location_misc                                             0.000000
# insurance_Medicaid                                                  0.000000
# insurance_Medicare                                                  0.000000
# insurance_Other                                                     0.000000
# Alanine Aminotransferase (ALT)_mean                                27.021277
# Alkaline Phosphatase_mean                                          27.163121
# Anion Gap_mean                                                      2.056738
# Asparate Aminotransferase (AST)_mean                               26.453901
# Base Excess_mean                                                   44.255319
# Bicarbonate_mean                                                    2.056738
# Bilirubin, Total_mean                                              27.801418
# Calcium, Total_mean                                                 6.808511
# Calculated Total CO2_mean                                          44.255319
# Chloride_mean                                                       1.985816
# Creatinine_mean                                                     1.773050
# Glucose_mean                                                        1.631206
# H_mean                                                             11.276596
# Hematocrit_mean                                                     2.127660
# Hemoglobin_mean                                                     2.056738
# I_mean                                                             11.276596
# INR(PT)_mean                                                        6.241135
# L_mean                                                             11.276596
# Lactate_mean                                                       41.985816
# MCH_mean                                                            2.127660
# MCHC_mean                                                           2.127660
# MCV_mean                                                            2.127660
# Magnesium_mean                                                      6.312057
# PT_mean                                                             6.170213
# PTT_mean                                                            6.028369
# Phosphate_mean                                                      6.808511
# Platelet Count_mean                                                 2.056738
# Potassium_mean                                                      2.624113
# RDW_mean                                                            2.127660
# RDW-SD_mean                                                         2.411348
# Red Blood Cells_mean                                                2.127660
# Sodium_mean                                                         2.553191
# Urea Nitrogen_mean                                                  1.843972
# White Blood Cells_mean                                              2.127660
# pCO2_mean                                                          44.255319
# pH_mean                                                            24.397163
# pO2_mean                                                           44.255319
# Anion Gap_std                                                      19.078014
# Bicarbonate_std                                                    19.078014
# Calcium, Total_std                                                 24.893617
# Chloride_std                                                       18.936170
# Creatinine_std                                                     18.581560
# Glucose_std                                                        16.737589
# H_std                                                              23.191489
# Hematocrit_std                                                     19.503546
# Hemoglobin_std                                                     19.148936
# I_std                                                              23.191489
# INR(PT)_std                                                        26.950355
# L_std                                                              23.191489
# MCH_std                                                            19.716312
# MCHC_std                                                           19.716312
# MCV_std                                                            19.716312
# Magnesium_std                                                      23.333333
# PT_std                                                             26.950355
# PTT_std                                                            25.390071
# Phosphate_std                                                      24.751773
# Platelet Count_std                                                 19.290780
# Potassium_std                                                      19.219858
# RDW_std                                                            19.716312
# RDW-SD_std                                                         20.000000
# Red Blood Cells_std                                                19.716312
# Sodium_std                                                         19.787234
# Urea Nitrogen_std                                                  18.439716
# White Blood Cells_std                                              19.716312
# pH_std                                                             45.460993
# Activity / Mobility (JH-HLM)_mean                                   1.489362
# Chloride (serum)_mean                                               3.758865
# Creatinine (serum)_mean                                             3.758865
# Current Dyspnea Assessment_mean                                    10.354610
# Daily Weight_mean                                                  44.822695
# GCS - Eye Opening_mean                                              0.780142
# GCS - Motor Response_mean                                           0.780142
# GCS - Verbal Response_mean                                          0.780142
# Glucose (serum)_mean                                                5.744681
# Glucose finger stick (range 70-100)_mean                           16.028369
# Heart Rate_mean                                                     0.567376
# Heart Rate Alarm - Low_mean                                         1.205674
# Heart rate Alarm - High_mean                                        1.205674
# Hematocrit (serum)_mean                                             4.113475
# Non Invasive Blood Pressure diastolic_mean                          4.326241
# Non Invasive Blood Pressure mean_mean                               4.326241
# Non Invasive Blood Pressure systolic_mean                           4.255319
# Non-Invasive Blood Pressure Alarm - High_mean                       5.319149
# Non-Invasive Blood Pressure Alarm - Low_mean                        5.319149
# O2 Flow_mean                                                       34.184397
# O2 Saturation Pulseoxymetry Alarm - Low_mean                        1.276596
# O2 saturation pulseoxymetry_mean                                    0.638298
# Pain Level_mean                                                    21.276596
# Pain Level Response_mean                                           36.808511
# Phosphorous_mean                                                   10.070922
# Potassium (serum)_mean                                              5.035461
# Resp Alarm - High_mean                                              1.347518
# Resp Alarm - Low_mean                                               1.276596
# Respiratory Rate_mean                                               0.709220
# Richmond-RAS Scale_mean                                             1.843972
# Secondary diagnosis_mean                                            4.326241
# Sodium (serum)_mean                                                 5.106383
# Strength L Arm_mean                                                 7.446809
# Strength L Leg_mean                                                 7.446809
# Strength R Arm_mean                                                 7.517730
# Strength R Leg_mean                                                 7.375887
# Temperature Fahrenheit_mean                                         2.907801
# Braden Score_mean                                                   1.702128
# Activity / Mobility (JH-HLM)_std                                    3.900709
# Chloride (serum)_std                                               23.829787
# Creatinine (serum)_std                                             23.829787
# Current Dyspnea Assessment_std                                     21.205674
# GCS - Eye Opening_std                                               3.333333
# GCS - Motor Response_std                                            3.546099
# GCS - Verbal Response_std                                           3.404255
# Glucose (serum)_std                                                25.177305
# Glucose finger stick (range 70-100)_std                            22.127660
# Heart Rate_std                                                      0.709220
# Heart Rate Alarm - Low_std                                          7.588652
# Heart rate Alarm - High_std                                         7.588652
# Hematocrit (serum)_std                                             24.184397
# Non Invasive Blood Pressure diastolic_std                           5.319149
# Non Invasive Blood Pressure mean_std                                5.177305
# Non Invasive Blood Pressure systolic_std                            5.248227
# Non-Invasive Blood Pressure Alarm - High_std                       12.056738
# Non-Invasive Blood Pressure Alarm - Low_std                        12.127660
# O2 Flow_std                                                        40.709220
# O2 Saturation Pulseoxymetry Alarm - Low_std                         7.872340
# O2 saturation pulseoxymetry_std                                     0.851064
# Pain Level_std                                                     28.865248
# Pain Level Response_std                                            47.588652
# Phosphorous_std                                                    28.368794
# Potassium (serum)_std                                              23.617021
# Resp Alarm - High_std                                               8.085106
# Resp Alarm - Low_std                                                8.014184
# Respiratory Rate_std                                                0.921986
# Richmond-RAS Scale_std                                              6.170213
# Secondary diagnosis_std                                            15.248227
# Sodium (serum)_std                                                 24.468085
# Strength L Arm_std                                                 10.992908
# Strength L Leg_std                                                 11.063830
# Strength R Arm_std                                                 11.063830
# Strength R Leg_std                                                 10.992908
# Temperature Fahrenheit_std                                          6.453901
# Braden Score_std                                                    8.581560
# dtype: float64

# %%
# Split the data into train and test
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

X = final.drop('actualhospitalmortality', axis=1, inplace=False).to_numpy()
y = final['actualhospitalmortality'].to_numpy()

sss.get_n_splits(X, y)

for train_index, test_index in sss.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
# Out:
# TRAIN: [1127   79  942  594  325 1043  347  613  717  392  538  759  209  271
#   602  232  453  433  588  367  766  365  936  241  848  801  404  448
#   737   18  852  270  931  545 1126  567  819  506  650   66 1117  185
#   430  398  144 1029  954  422  997  896  150 1018  623  932  410  383
#   692  510  289   32  206  878  492  564  843  184  517  790  520  330
#   706 1039  820  204   38  375  840  220  792  389  738  529 1057  898
#    99  568  118  208 1084  577  548  504  550  440   40  298  388  746
#  1089  980  501  156  718  626  691  360  608  845  945  155   26 1092
#   162 1080  134   42  227  164  480  481  167  502   93 1013  257  317
#    88  891  989  832  559 1137 1066   90  434  161  833  247  590  273
#  1094  583 1100    3  327  350  121  265  686  157    0  497  800  809
#   673  539  301  970    4  535  414   76 1106  874  395  498  734  870
#   418 1067  533  552   11   36 1025 1076   62  743  165  451  470  782
#  1001    9  816  181 1033   44  901  785   55   89   48  307  731 1112
#   258  897  379 1091  854 1096  124  225  923  724  126  708  466  238
#   880  921  722  419  804  147  756  834  366  604  469 1020  677  115
#   174  313  344 1042  358 1007  168  518  532  770 1056  554  390   72
#   755  883 1008   28  615  217   43 1061  201  253   51  310  857  380
#   359  420 1104  131 1132  397  824  622  409 1082 1049  659  259  628
#  1051  226  975 1121  200 1133  670  447   71  467  934 1142 1017  523
#   710  733  457  701  246  769  491  575  348  188 1070  798  649  573
#   442 1122  400 1011  102  598   19  985   92  372  885 1022 1124 1138
#   326  903  652  531  856  519  858  191   29  689   10  308  405  449
#   254  234  443  553  435  648  551  464  509  977  427  562  871  655
#   459  595 1059  762  805  839  223  387  665  735  401  916  371  476
#   849  561  180  314  543  572   63  309  831  304  412  305  941  570
#    67  475  793  763 1118  490   16  956  951  574  645  611  297  566
#   825  557  918  537  193  288  182 1046 1010  696 1038  875   21  322
#   633  483  944  283  120 1053 1130   91  713  925  986  236  133  374
#   909 1031  661  444  250  760  739  332  571  784  884  439  712  998
#   143   39  641   77   59  667  707  807  465   57  651  394  508  140
#   771  920  363    6  959  585  455  424  437  606  479  302  614  913
#  1113  468  403  639  616  461 1004  778  555  319   84  794  744  591
#   660  937  922  953  274  781  179  867  939  279 1077  117  967  429
#   500  503  362  482   14  112  576  947  349  530  866  542 1014  138
#   991 1026  216   95 1114 1075 1134 1111   22  779  569  421  995  544
#   653  935   45  107   78  528  472   87  750  252  416  943  431  563
#   104  159  978  895  927  752  488   34  145 1035  924  813 1072   20
#    56  741 1139  671  894  323  237  688  329  589  219  119  163  125
#   910  624  938  882  135 1140  487  438  171  926  907 1125  285 1103
#   484  334  196  393  740 1023  865  846 1086  261  635 1062  646  693
#   636  351  592  266 1135  597  242  836  662  244  396 1116  682  721
#   821  526  842  748  128  292  546 1015  177  828 1069  879  957 1083
#  1009  382  340  357  129 1078 1141    8  765  260  291  777  841   60
#  1129 1000  192  928  153  248  773  560  251  106  328  186  130  818
#   965  549 1063  873  522  864  335  462  345  786 1090  240  407  311
#   198  607  703  111  720   74  690  971  853  893  477  408  700   97
#  1102  513  496  210   86 1041  152  346  859  814  127  906  725  391
#   280  256  290 1048 1098  355  982   27  863  704  749  536   80 1019
#  1097  948 1047 1016  169  668  303  471  593   50  726  847  715  399
#   364  194  578  666 1065  376  802  829  281  212  654 1109  994  946
#   239  337  976   23  904  605 1052    5  599  757   81  972   17  377
#   683  579  761  609 1120  154  369  417  450  137  294  929  175  764
#   617  791  672  961  228   73  580  581  876  658  600  276  534  402
#   116  495  675  795  610  647  657  356 1050  415  170 1055 1060  272
#   277  775  714   61  293   75  747  284  803  952  851  601  315   24
#   728  702  745  516  221  872  142  634    1  629  979  949  630  736
#   255  642  914 1030  940  222 1024  195  103  278  452  381  905  620
#   262 1095  245  342  218  231  139 1088 1058   35 1071  463  586  621
#   850 1108  275  983  776  987  768  249   47  812  267  730  911  960
#  1079  183  268    2  868 1093  758  787  823  199  123  912  547  353
#   742   68  406  341 1003  669 1099  158 1032  788  524  767  521  899
#   810  478  320  933  565 1054  780  680  999 1037  187  697  676  711
#   287  886 1128 1040  108 1107  900 1136 1131 1045  489  485  835  384
#   992  984  890  386   49  827  732  190   33  189  339  678  230  499
#   830   83  958  299] TEST: [  58  637 1115  955  149  695   30  235  754  312  789  727  441 1081
#   838  454  243  962  966  974  318  716  797  338  136   64  930 1036
#   881   94  988  664  950  558   15  445  855  361 1068  324   37  587
#   296  173  295  681  887  817  627  229  969  877  612  808 1101  694
#   122   54  963 1085  515  663  603   31  687  837  644   69  132  286
#  1073  729  321  233  166  783  160 1110  202  474  908  197  176  282
#  1034  640  473  263  370  426  214  368  316   25  723  632  993  300
#  1123 1006   46  105  844 1044  684  306  719  148  699  494  861   70
#    12  822  541  860   13  511  423  203  264  753  892  698  331 1105
#   373  110  458   65  432  889  826  460  919  582 1012  436  869  333
#   638  751  456  964  981  968   53  618  674  507  207  113  505  213
#   996  656  584  625  685  596  973  888 1005  336  679  425  514  811
#   269  862  411  141  224 1021  540  352 1002   52  915  512  486  643
#    98  151  796  343 1064  631  815  990 1027  146  527 1119  101  806
#   354 1074 1028  413  774   96  619  556  205  525  385    7   41  772
#  1087  799  109   82  114  428  172  378  178  917  493  705   85  100
#   902  446  709  211  215]

# %%
np.save('X_train_static_24', X_train)
np.save('X_test_static_24', X_test)
np.save('y_train_static_24', y_train)
np.save('y_test_static_24', y_test)

# %%
X_train_static_6 = np.load('X_train_static_6.npy')
X_test_static_6 = np.load('X_test_static_6.npy')
y_train_static_6 = np.load('y_train_static_6.npy')
y_test_static_6 = np.load('y_test_static_6.npy')

# %%
# Train and test split
np.shape(X_train_static_6), np.shape(X_test_static_6)
# Out:
# ((1128, 174), (282, 174))

# %%
# LOS distribution
print((np.mean(X_train_static_6[:,0])/(64*24), np.std(X_train_static_6[:,0])/(64*24), np.median(X_train_static_6[:,0])/(64*24)))
print(np.mean(X_test_static_6[:,0])/(64*24), np.std(X_test_static_6[:,0])/(64*24), np.median(X_test_static_6[:,0])/(64*24))
# Out:
# (3.687854542593208, 4.886174456135874, 2.1766927083333334)
# 3.2416780175704294 3.2018417858890795 2.0694118923611113

# %%
# Women vs Men distribution
unique, counts = np.unique(X_train_static_6[:,1], return_counts=True)
result = dict(zip(unique, counts))
print(result)

unique, counts = np.unique(X_test_static_6[:,1], return_counts=True)
result = dict(zip(unique, counts))
print(result)
# Out:
# {0.0: 543, 1.0: 585}
# {0.0: 126, 1.0: 156}

# %%
# Age distribution
print(np.mean(X_train_static_6[:,2]), np.std(X_train_static_6[:,2]), np.median(X_train_static_6[:,2]))
print(np.mean(X_test_static_6[:,2]), np.std(X_test_static_6[:,2]), np.median(X_test_static_6[:,2]))
# Out:
# 70.8936170212766 14.470538486189023 72.0
# 71.01418439716312 15.062039935872813 72.0

# %%
# Death distribution
unique, counts = np.unique(y_train_static_6, return_counts=True)
result = dict(zip(unique, counts))
print(result)

unique, counts = np.unique(y_test_static_6, return_counts=True)
result = dict(zip(unique, counts))
print(result)
# Out:
# {0.0: 998, 1.0: 130}
# {0.0: 250, 1.0: 32}
